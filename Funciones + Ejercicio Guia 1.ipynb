# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 6, 0.01)

y = 120*x+2000

plt.plot(x, y)

plt.axis([0, 6, 0, 2800])

plt.xlabel("Energia utilizada ({kWh}).")

plt.ylabel("Costo para el usuario ($).")

plt.title("Costo para el usuario segun uso de energia.")

plt.grid(True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def m(s):
    return 100*s

segundo = 45
print(f"A los {segundo} segundos, se obtienen {m(segundo)} megabits.")

segundo2 = 90
print(f"A los {segundo2} segundos, se obtienen {m(segundo2)} megabits.")

segundo3 = 1*60*60
print(f"A los {segundo3} segudos cuales equivalen a una hora, se obtienen {m(segundo3)} megabits.")
# Out:
# A los 45 segundos, se obtienen 4500 megabits.
# A los 90 segundos, se obtienen 9000 megabits.
# A los 3600 segudos cuales equivalen a una hora, se obtienen 360000 megabits.

# %%
def tabla_datos():
    for i in range(0, 1100, 100):
        print(f"{i} segundos | {m(i)} megabits")

tabla_datos()
# Out:
# 0 segundos | 0 megabits
# 100 segundos | 10000 megabits
# 200 segundos | 20000 megabits
# 300 segundos | 30000 megabits
# 400 segundos | 40000 megabits
# 500 segundos | 50000 megabits
# 600 segundos | 60000 megabits
# 700 segundos | 70000 megabits
# 800 segundos | 80000 megabits
# 900 segundos | 90000 megabits
# 1000 segundos | 100000 megabits

# %%
#Ejercicio 4

import matplotlib.pyplot as plt
import numpy as np

# 1.
def l(h):
    return 1.85*h

# 2.
#Variable dependiente: La longitud del hable
#Variable independiente: El tiempo transcurrido

# 3.
#El dominio de la funcion son todos los valores que toma h, en este caso las horas que va desde [0, 3567]

# 4.
h = np.arange(0, 3567, 1)

plt.plot(h, l(h))

plt.title("Relacion entre tiempo y distancia para instalar el cable submarino")
plt.xlabel("Tiempo transcurrido (h)")
plt.ylabel("Distancia recorrida (km)")

plt.grid(True)
plt.show()

# 5.
time = l(148)
meters = time*1000
print(f"Al transcurrir 148 horas, se instalan {meters} metros de cable")

time2 = l(2300)
meters2 = time2*1000
print(f"Al transcurrir 2300 horas, se instalan {meters2} metros de cable")

# 6.
h2 = 3480 / 1.85
print(f"Al instalarse 3480 kilometros de cable, transcurren {h2} horas")

# 7.
h = 6600 / 1.85
print(f"El tiempo que demoro el barco en instalar el cable son {h} horas.")
# Out:
# Al transcurrir 148 horas, se instalan 273800.0 metros de cable
# Al transcurrir 2300 horas, se instalan 4255000.0 metros de cable
# Al instalarse 3480 kilometros de cable, transcurren 1881.081081081081 horas
# El tiempo que demoro el barco en instalar el cable son 3567.5675675675675 horas.

# %%
#Ejercicio5

import matplotlib.pyplot as plt
import numpy as np


def f(t):
    return 0.4*t

def g(t):
    return 0.3*t

# 1.
#Grafico de tiempo y distancia entre metro de santiago y buses red 

t = np.arange(0, 100, 1)
plt.plot(t, f(t), label = 'f(t)')
plt.plot(t, g(t), label = 'g(t)')
plt.title('Relacion tiempo y distancia')
plt.ylabel('Kilometros recorridos (km)')
plt.xlabel('Minutos recorridos (m)')
plt.legend()
plt.grid(True)
plt.show()

# 2.
t = 1.2 * 9 + 0.5 * 8
print(f"El extremo superior del dominio es: {t:.1f}")

# 3.
#El medio de transporte mas rapido es el metro de santiago, ya que a los mismos minutos transcurridos, el metro recorre mas distancia que los buses Red, siendo mas rapido

# 4.
time = 6 / 0.4
time2 = 6 / 0.3

print(f"Tiempo demorado en metro: {time:.1f}")
print(f"Tiempo demorado en bus Red: {time2:.1f}")
# Out:
# El extremo superior del dominio es: 14.8
# Tiempo demorado en metro: 15.0
# Tiempo demorado en bus Red: 20.0

# %%
#Ejercicio 6

import matplotlib.pyplot as plt
import numpy as np

def T(t):
    return -0.5*t**2 + 3*t + 20

# 1.
#Variable dependiente: La temperatura del servidor en °C -> T(t)
#Variable independiente: El tiempo que transcurre en horas -> t

# 2.
#El dominio de la funcion T(t) va es [0, 9]

# 3.
t = np.arange(0, 9, 0.01)
plt.plot(t, T(t), color = 'red', label = "Temperatura del servidor")
plt.title('Relacion tiempo y grados')
plt.ylabel('Temperatura (°C)')
plt.xlabel('Tiempo (h)')
plt.legend()
plt.grid(True)
plt.show()

# 4.
#A las 3 horas alcanza su maxima temperatura
print(f"La temperatura que alcanza el servido a las 3 horas es: {T(3):.1f}")

# 5.
print(f"A las 13:00 horas el servidor alcanza {T(5):.1f} °C")
print(f"A las 17:00 horas, el servido alcanza {T(9):.1f} °C")
# Out:
# La temperatura que alcanza el servido a las 3 horas es: 24.5
# A las 13:00 horas el servidor alcanza 22.5 °C
# A las 17:00 horas, el servido alcanza 6.5 °C

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return 1000 / (1 + 9*np.exp(-0.5*x))

# 1.
# Varibable dependiente: La cantidad de usuarios f(x)
# Variable independiente: El tiempo transcurrido en meses x

# 2.
# Determine la cantidad de usuarios transcurridos 12 meses.
months : int = 12
totalUsers = f(months)

print(f"La cantidad de usuarios en la red social a los {months} meses son: {totalUsers:.0f}")
print()

# 3.
# Grafique la función, utilizando la librería Matplotlib, para los primeros dos años de funcionamiento.
x = np.arange(0, 24, 0.01)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Cantidad de usurios segun el tiempo transcurrido')
plt.ylabel('Cantidad de usuarios')
plt.xlabel('Tiempo transcurrido en meses')
plt.legend()
plt.grid(True)
plt.show()

# 4.
# ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?
def x(t):
    return 1000 / (1 + 9*np.exp(-0.5*t)) - 800

t = 0
sol = fsolve(x, t)

print(f"La cantidad de meses transcurrido a cuando se alcanzan los 800 usuarios son: {sol[0]:.1f} mese aproximados")
print()
# Out:
# La cantidad de usuarios en la red social a los 12 meses son: 978
# La cantidad de meses transcurrido a cuando se alcanzan los 800 usuarios son: 7.2 mese aproximados
